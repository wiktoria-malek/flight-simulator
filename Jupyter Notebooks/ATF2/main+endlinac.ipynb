# %% [markdown]
# # ATF LINAC RF_TRACK LATTICE + endLINAC

# %%
#########################################
# Python libraries                      #
#########################################
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import RF_Track
import numpy
import matplotlib.pyplot as plt

# %%
import RF_Track

################# Cavities #################################

a0 = 25.5e+6 # V/m, principal Fourier coefficient
#a0 = 0 # V/m, principal Fourier coefficient
freq = 2855.9822615999997e+6 # Hz
ph_adv = 2*np.pi/3 # radian, phase advance per cell
n_cells = -85 # number of cells, negative sign indicates a start from the beginning of the cell
TW = RF_Track.TW_Structure(a0, 0, freq, ph_adv, n_cells) # 0=el primer elemento del armonico
phid=-91.67+90 #LAG -.2546388888888886 [2*pi]
TW.set_phid(phid)

BCph_adv=2.0908741;
BCBn_cells=-85;
TWB1 = RF_Track.TW_Structure(0, 0, freq, BCph_adv, BCBn_cells) # TW Bunching
BCphid=-90+90
TWB1.set_phid(BCphid)

BC2ph_adv=2.0958035;
BC2Bn_cells=-85;
TWB2 = RF_Track.TW_Structure(0, 0, freq, BC2ph_adv, BC2Bn_cells) # TW Bunching 2
BCphid=-90+90
TWB2.set_phid(BCphid)
TWB2.get_length()

####################Lattice ##########################################

L = RF_Track.Lattice()
charge = -1 # single-particle charge, in units of e
Pc = 80# reference momentum, MeV/c
P_Q = Pc / charge # MV/c, reference rigidity

pos_actual = 0.0 

# ----------------- QA1L -----------------
LQA1L = 0.132
pos_QA1L = 1.356
drift = pos_QA1L - LQA1L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(RF_Track.Quadrupole(LQA1L, P_Q, 1.1835109401030304))
pos_actual = pos_QA1L + LQA1L/2

# ----------------- QA2L -----------------
LQA2L = 0.182
pos_QA2L = 1.703
drift = pos_QA2L - LQA2L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(RF_Track.Quadrupole(LQA2L, P_Q, -9.264115425347802))
pos_actual = pos_QA2L + LQA2L/2

# ----------------- QA3L -----------------
LQA3L = 0.182
pos_QA3L = 2.128
drift = pos_QA3L - LQA3L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(RF_Track.Quadrupole(LQA3L, P_Q, 7.601904693021979))
pos_actual = pos_QA3L + LQA3L/2

# ----------------- QA4L ------------------
LQA4L = 0.182
pos_QA4L = 4.774
drift = pos_QA4L - LQA4L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(RF_Track.Quadrupole(LQA4L, P_Q, -8.309547432909891))
pos_actual = pos_QA4L + LQA4L/2

# ----------------- QA5L -----------------
LQA5L = 0.132
pos_QA5L = 5.171
drift = pos_QA5L - LQA5L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(RF_Track.Quadrupole(LQA5L, P_Q, 10.368563413319697))
pos_actual = pos_QA5L + LQA5L/2

# ----------------- CA1L -----------------
LCA1L = TW.get_length()
pos_CA1L = 7.3835
drift = pos_CA1L - LCA1L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(TW)
L.unset_t0()
pos_actual = pos_CA1L + LCA1L/2

# ----------------- QD1L -----------------
LQD1L = 0.132
pos_QD1L = 9.548499999999997
drift = pos_QD1L - LQD1L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(RF_Track.Quadrupole(LQD1L, P_Q, -6.394111798396212))
pos_actual = pos_QD1L + LQD1L/2

# ----------------- QF1L -----------------
LQF1L = 0.182
pos_QF1L = 9.948499999999996
drift = pos_QF1L - LQF1L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(RF_Track.Quadrupole(LQF1L, P_Q, 8.468997394013186))
pos_actual = pos_QF1L + LQF1L/2

# ----------------- QD2L -----------------
LQD2L = 0.132
pos_QD2L = 10.348499999999994
drift = pos_QD2L - LQD2L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(RF_Track.Quadrupole(LQD2L, P_Q, -6.415397177518939))
pos_actual = pos_QD2L + LQD2L/2

# ----------------- CA2L -----------------
LCA2L = TW.get_length()
pos_CA2L = 12.142714999999995
drift = pos_CA2L - LCA2L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(TW)
L.unset_t0()
pos_actual = pos_CA2L + LCA2L/2

# ----------------- QF2L -----------------
LQF2L = 0.125
pos_QF2L = 14.143499999999994
drift = pos_QF2L - LQF2L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(RF_Track.Quadrupole(LQF2L, P_Q, 4.6362775786152))
pos_actual = pos_QF2L + LQF2L/2

# ----------------- QD3L -----------------
LQD3L = 0.125
pos_QD3L = 14.894999999999994
drift = pos_QD3L - LQD3L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(RF_Track.Quadrupole(LQD3L, P_Q, -4.7315774972976))
pos_actual = pos_QD3L + LQD3L/2

# ----------------- CA3L -----------------
LCA3L = TW.get_length()
pos_CA3L = 17.006999999999994
drift = pos_CA3L - LCA3L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(TW)
L.unset_t0()
pos_actual = pos_CA3L + LCA3L/2

# ----------------- QF3L -----------------
LQF3L = 0.125
pos_QF3L = 18.986999999999995
drift = pos_QF3L - LQF3L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(RF_Track.Quadrupole(LQF3L, P_Q, 5.8107864654864))
pos_actual = pos_QF3L + LQF3L/2

# ----------------- QD4L -----------------
LQD4L = 0.125
pos_QD4L = 19.73699999999999
drift = pos_QD4L - LQD4L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(RF_Track.Quadrupole(LQD4L, P_Q, -5.1676165334704))
pos_actual = pos_QD4L + LQD4L/2

# ----------------- CA4L -----------------
LCA4L = TW.get_length()
pos_CA4L = 21.87099999999999
drift = pos_CA4L - LCA4L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(TW)
pos_actual = pos_CA4L + LCA4L/2

# ----------------- QF4L -----------------
LQF4L = 0.125
pos_QF4L = 23.84099999999999
drift = pos_QF4L - LQF4L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(RF_Track.Quadrupole(LQF4L, P_Q, 7.6235715827536))
pos_actual = pos_QF4L + LQF4L/2

# ----------------- QD5L -----------------
LQD5L = 0.125
pos_QD5L = 24.491999999999987
drift = pos_QD5L - LQD5L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(RF_Track.Quadrupole(LQD5L, P_Q, -6.7358412875152))
pos_actual = pos_QD5L + LQD5L/2

# ----------------- CB1L -----------------
LCB1L = TWB1.get_length()
pos_CB1L = 26.520499999999988
drift = pos_CB1L - LCB1L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(TWB1)
pos_actual = pos_CB1L + LCB1L/2

# ----------------- QF5L -----------------
LQF5L = 0.125
pos_QF5L = 28.486499999999985
drift = pos_QF5L - LQF5L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(RF_Track.Quadrupole(LQF5L, P_Q, 7.6898162668192))
pos_actual = pos_QF5L + LQF5L/2

# ----------------- QD6L -----------------
LQD6L = 0.125
pos_QD6L = 29.13649999999998
drift = pos_QD6L - LQD6L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(RF_Track.Quadrupole(LQD6L, P_Q, -6.8687757100048))
pos_actual = pos_QD6L + LQD6L/2

# ----------------- CA5L -----------------
LCA5L = TW.get_length()
pos_CA5L = 31.180499999999984
drift = pos_CA5L - LCA5L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(TW)
pos_actual = pos_CA5L + LCA5L/2

# ----------------- CA6L -----------------
LCA6L = TW.get_length()
pos_CA6L = 34.78399999999999
drift = pos_CA6L - LCA6L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(TW)
pos_actual = pos_CA6L + LCA6L/2

# ----------------- QF6L -----------------
LQF6L = 0.125
pos_QF6L = 36.74699999999999
drift = pos_QF6L - LQF6L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(RF_Track.Quadrupole(LQF6L, P_Q, 4.4820119116136))
pos_actual = pos_QF6L + LQF6L/2

# ----------------- QD7L -----------------
LQD7L = 0.125
pos_QD7L = 37.397
drift = pos_QD7L - LQD7L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(RF_Track.Quadrupole(LQD7L, P_Q, -4.4944090948816))
pos_actual = pos_QD7L + LQD7L/2

# ----------------- CA7L -----------------
LCA7L = TW.get_length()
pos_CA7L = 39.43000000000001
drift = pos_CA7L - LCA7L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(TW)
pos_actual = pos_CA7L + LCA7L/2

# ----------------- CA8L -----------------
LCA8L = TW.get_length()
pos_CA8L = 43.03397000000001
drift = pos_CA8L - LCA8L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(TW)
pos_actual = pos_CA8L + LCA8L/2

# ----------------- QS5L -----------------
LQS5L = 0.125
pos_QS5L = 45.298760000000016
drift = pos_QS5L - LQS5L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(RF_Track.Quadrupole(LQS5L, P_Q, 0.9884761807816))
pos_actual = pos_QS5L + LQS5L/2

# ----------------- CA9L -----------------
LCA9L = TW.get_length()
pos_CA9L = 47.26726000000002
drift = pos_CA9L - LCA9L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(TW)
pos_actual = pos_CA9L + LCA9L/2

# ----------------- CA10L -----------------
LCA10L = TW.get_length()
pos_CA10L = 50.872260000000026
drift = pos_CA10L - LCA10L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(TW)
pos_actual = pos_CA10L + LCA10L/2

# ----------------- QS6L -----------------
LQS6L = 0.125
pos_QS6L = 53.137260000000026
drift = pos_QS6L - LQS6L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(RF_Track.Quadrupole(LQS6L, P_Q, -1.1188273572312))
pos_actual = pos_QS6L + LQS6L/2

# ----------------- CA11L -----------------
LCA11L = TW.get_length()
pos_CA11L = 55.10826000000003
drift = pos_CA11L - LCA11L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(TW)
pos_actual = pos_CA11L + LCA11L/2

# ----------------- CA12L -----------------
LCA12L = TW.get_length()
pos_CA12L = 58.397760000000034
drift = pos_CA12L - LCA12L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(TW)
pos_actual = pos_CA12L + LCA12L/2

# ----------------- QS7L -----------------
LQS7L = 0.125
pos_QS7L = 60.66226000000003
drift = pos_QS7L - LQS7L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(RF_Track.Quadrupole(LQS7L, P_Q, 0.8013307329232))
pos_actual = pos_QS7L + LQS7L/2

# ----------------- CB2L -----------------
LCB2L = TWB2.get_length()
pos_CB2L = 62.63276000000003
drift = pos_CB2L - LCB2L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(TWB2)
pos_actual = pos_CB2L + LCB2L/2

# ----------------- CA13L -----------------
LCA13L = TW.get_length()
pos_CA13L = 65.91976000000003
drift = pos_CA13L - LCA13L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(TW)
pos_actual = pos_CA13L + LCA13L/2

# ----------------- CA14L -----------------
LCA14L = TW.get_length()
pos_CA14L = 69.20926000000003
drift = pos_CA14L - LCA14L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(TW)
pos_actual = pos_CA14L + LCA14L/2

# ----------------- QS8L -----------------
LQS8L = 0.125
pos_QS8L = 71.47405000000003
drift = pos_QS8L - LQS8L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(RF_Track.Quadrupole(LQS8L, P_Q, -0.522816766032))
pos_actual = pos_QS8L + LQS8L/2

# ----------------- CA15L -----------------
LCA15L = TW.get_length()
pos_CA15L = 73.44305000000003
drift = pos_CA15L - LCA15L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(TW)
pos_actual = pos_CA15L + LCA15L/2

# ----------------- CA16L -----------------
LCA16L = TW.get_length()
pos_CA16L = 76.73305000000002
drift = pos_CA16L - LCA16L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(TW)
pos_actual = pos_CA16L + LCA16L/2

# ----------------- QM1L -----------------
LQM1L = 0.175
pos_QM1L = 78.59605000000002
drift = pos_QM1L - LQM1L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(RF_Track.Quadrupole(LQM1L, P_Q, 1.4909714285714286))
pos_actual = pos_QM1L + LQM1L/2

# ----------------- QM2L -----------------
LQM2L = 0.325
pos_QM2L = 79.61655000000002
drift = pos_QM2L - LQM2L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(RF_Track.Quadrupole(LQM2L, P_Q, -1.894584615384615))
pos_actual = pos_QM2L + LQM2L/2

# ----------------- QM3L -----------------
LQM3L = 0.175  # longitud del cuadrupolo QM3L
pos_QM3L = 81.59355000000002
drift = pos_QM3L - LQM3L/2 - pos_actual
L.append(RF_Track.Drift(drift))
L.append(RF_Track.Quadrupole(LQM3L, P_Q, 3.646114285714286))  
pos_actual = pos_QM3L + LQM3L/2

# ----------------- IPZL -----------------
pos_IPZL = 83.40465000000002
drift = pos_IPZL - pos_actual
L.append(RF_Track.Drift(drift))
L.get_length()


from cpymad.madx import Madx 
# madx = Madx(stdout=True)
madx = Madx()
import RF_Track
import numpy
import matplotlib.pyplot as plt
madx.call('End_linac.madx');

Linacend= RF_Track.Lattice("linacend.tws");
L.append(Linacend);

# %%
############ Adjusting strength with autophase#############
mass = RF_Track.electronmass # MeV/c^2
charge = -1 # single-particle charge, in units of e
Q=charge
population = 1e+10 # number of real particles per bunch
Pc = 80# reference momentum, MeV/c
P_Q = Pc / charge # MV/c, reference rigidity
Pi=80
# Define the reference particle
P0 = RF_Track.Bunch6d(mass, population, charge, numpy.array([0,0,0,0,0,Pi]).T)

# We use "autophase" to set the phases and to determine P_max, the maximum final momentum
TWL = RF_Track.Lattice()
TWL.append(TW)
TWL.unset_t0()
P_max = TWL.autophase(P0) # MeV/c

# The momentum gain is
P_gain = P_max - Pi   # MeV/c
Quads = L.get_quadrupoles()

P=Pi
Quads[0].set_K1(P/Q, Quads[0].get_K1(P_Q));
Quads[1].set_K1(P/Q, Quads[1].get_K1(P_Q));
Quads[2].set_K1(P/Q, Quads[2].get_K1(P_Q));
Quads[3].set_K1(P/Q, Quads[3].get_K1(P_Q));
Quads[4].set_K1(P/Q, Quads[4].get_K1(P_Q));
P += P_gain
Quads[5].set_K1(P/Q, Quads[5].get_K1(P_Q));
Quads[6].set_K1(P/Q, Quads[6].get_K1(P_Q));
Quads[7].set_K1(P/Q, Quads[7].get_K1(P_Q));
P += P_gain
Quads[8].set_K1(P/Q, Quads[8].get_K1(P_Q));
Quads[9].set_K1(P/Q, Quads[9].get_K1(P_Q));
P += P_gain
Quads[10].set_K1(P/Q, Quads[10].get_K1(P_Q));
Quads[11].set_K1(P/Q, Quads[11].get_K1(P_Q));
P += P_gain
Quads[12].set_K1(P/Q, Quads[12].get_K1(P_Q));
Quads[13].set_K1(P/Q, Quads[13].get_K1(P_Q));
Quads[14].set_K1(P/Q, Quads[14].get_K1(P_Q));
Quads[15].set_K1(P/Q, Quads[15].get_K1(P_Q));
P += P_gain
P += P_gain
Quads[16].set_K1(P/Q, Quads[16].get_K1(P_Q));
Quads[17].set_K1(P/Q, Quads[17].get_K1(P_Q));
P += P_gain
P += P_gain
Quads[18].set_K1(P/Q, Quads[18].get_K1(P_Q));
P += P_gain
P += P_gain
Quads[19].set_K1(P/Q, Quads[19].get_K1(P_Q));
P += P_gain
P += P_gain
Quads[20].set_K1(P/Q, Quads[20].get_K1(P_Q));
P += P_gain
P += P_gain
Quads[21].set_K1(P/Q, Quads[21].get_K1(P_Q));
P += P_gain
P += P_gain
Quads[22].set_K1(P/Q, Quads[22].get_K1(P_Q));
Quads[23].set_K1(P/Q, Quads[23].get_K1(P_Q));
Quads[24].set_K1(P/Q, Quads[24].get_K1(P_Q));

Quads[25].set_K1(P/Q, Quads[25].get_K1(P_Q));
Quads[26].set_K1(P/Q, Quads[26].get_K1(P_Q));
Quads[27].set_K1(P/Q, Quads[27].get_K1(P_Q));
Quads[28].set_K1(P/Q, Quads[28].get_K1(P_Q));

# %%
# Bunch parameters
mass = RF_Track.electronmass # MeV/c^2
charge = -1 # single-particle charge, in units of e
population = 1e+10 # number of real particles per bunch
Pc = 80# reference momentum, MeV/c
P_Q = Pc / charge # MV/c, reference rigidity

# Define Twiss parameters
Twiss = RF_Track.Bunch6d_twiss()
Twiss.emitt_x = 24.7e-4 # mm.mrad, normalized emittances
Twiss.emitt_y = 24.7e-4 # mm.mrad
Twiss.alpha_x = -3.599
Twiss.alpha_y = -10.419
Twiss.beta_x = 0.451 # m
Twiss.beta_y = 2.236 # m

# Create the bunch
B0 = RF_Track.Bunch6d(mass, population, charge, Pc, Twiss, 100)
B1 = L.track(B0)
T = L.get_transport_table('%S %beta_x %beta_y %emitt_x %emitt_y %sigma_x %sigma_y %mean_P %alpha_x %alpha_y');
#plt.figure(figsize=(14, 7))
plt.plot(T[:,0], (T[:,1]), linewidth=2, label=r'$\beta_x$')
plt.plot(T[:,0], (T[:,2]), linewidth=2, label=r'$\beta_y$')
plt.legend()
plt.xlabel('s [m]')
plt.ylabel(r'$\beta [m]$')

# %%
plt.plot(T[:,0], ((T[:,3]-Twiss.emitt_x)/Twiss.emitt_x)*1, linewidth=2, label=r'$\epsilon_x$')
plt.plot(T[:,0], ((T[:,4]-Twiss.emitt_y)/Twiss.emitt_y)*1, linewidth=2, label=r'$\epsilon_y$')
plt.ylim(-1, 1)
plt.xlabel('s [m]')
plt.ylabel(r'$\Delta \epsilon / \epsilon_0$')
plt.legend()

# %%
plt.plot(T[:,0], T[:,5], linewidth=2, label=r'$\sigma_x$')
plt.plot(T[:,0], T[:,6], linewidth=2, label=r'$\sigma_y$')
plt.xlabel('s [m]')
plt.ylabel(r'$\sigma$ [mm]')
plt.legend()

# %%
plt.plot (T[:, 0], T[:, 7])
plt.xlabel ('s [m]')
plt.ylabel ('K [MeV]')

# %%
T[-1, 7]
